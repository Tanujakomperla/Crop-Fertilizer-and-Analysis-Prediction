# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
wide = (21, 9)
large_square = (30, 30)

# %%
ds=pd.read_csv('C:/Users/Tanuja/OneDrive/Desktop/CROP/cropFertilizerandanalysis Prediction.csv')
ds.head(20)
# Out:
#     Temparature  Humidity   Moisture Soil Type    Crop Type  Nitrogen  \
# 0            26         52        38     Sandy        Maize        37
# 1            29         52        45     Loamy    Sugarcane        12
# 2            34         65        62     Black       Cotton         7
# 3            32         62        34       Red      Tobacco        22
# 4            28         54        46    Clayey        Paddy        35
# 5            26         52        35     Sandy       Barley        12
# 6            25         50        64       Red       Cotton         9
# 7            33         64        50     Loamy        Wheat        41
# 8            30         60        42     Sandy      Millets        21
# 9            29         58        33     Black    Oil seeds         9
# 10           27         54        28    Clayey       Pulses        13
# 11           31         62        48     Sandy        Maize        14
# ...

# %%
ds.shape
# Out:
# (99, 9)

# %%
ds.info()
ds.columns
ds.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temparature      99 non-null     int64
#  1   Humidity         99 non-null     int64
#  2   Moisture         99 non-null     int64
#  3   Soil Type        99 non-null     object
#  4   Crop Type        99 non-null     object
#  5   Nitrogen         99 non-null     int64
#  6   Potassium        99 non-null     int64
#  7   Phosphorous      99 non-null     int64
#  8   Fertilizer Name  99 non-null     object
# dtypes: int64(6), object(3)
# memory usage: 7.1+ KB
#        Temparature  Humidity    Moisture   Nitrogen  Potassium  Phosphorous
# count    99.000000  99.000000  99.000000  99.000000  99.000000    99.000000
# mean     30.282828  59.151515  43.181818  18.909091   3.383838    18.606061
# std       3.502304   5.840331  11.271568  11.599693   5.814667    13.476978
# ...

# %%
ds.dtypes
ds.isnull().sum()
# Out:
# Temparature        0
# Humidity           0
# Moisture           0
# Soil Type          0
# Crop Type          0
# Nitrogen           0
# Potassium          0
# Phosphorous        0
# Fertilizer Name    0
# dtype: int64

# %%
#unique values in dataset
ds.nunique()
# Out:
# Temparature        14
# Humidity           13
# Moisture           41
# Soil Type           5
# Crop Type          11
# Nitrogen           24
# Potassium          13
# Phosphorous        32
# Fertilizer Name     7
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=ds, x='Crop Type')
plt.xlabel('Crop Type')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=ds, x='Soil Type')
plt.xlabel('Soil Type')
plt.ylabel('Count')
plt.show()

# %%
# Group the data by soil type
ds1 = ds.groupby("Soil Type")["Nitrogen"].mean()
ds1.plot(kind="bar")
# Show the plot
plt.show()

# %%
# Group the data by soil type
ds1 = ds.groupby("Soil Type")["Potassium"].mean()
ds1.plot(kind="bar")
# Show the plot
plt.show()

# %%
# Group the data by soil type
ds1 = ds.groupby("Soil Type")["Phosphorous"].mean()
ds1.plot(kind="bar")
# Show the plot
plt.show()

# %%
ds.hist()
plt.show()

# %%
ds["Temparature"].value_counts()
ds["Humidity "].value_counts()
# Out:
# 60    15
# 58    12
# 52    11
# 65    11
# 54    11
# 62    10
# 50     7
# 68     6
# 64     5
# 53     5
# 70     3
# 67     2
# 72     1
# Name: Humidity , dtype: int64

# %%
Temparature = ds.groupby('Temparature')['Humidity '].mean().sort_values(ascending=False)

# %%
# Create horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 20))
ax.barh(Temparature.index, Temparature.values)
ax.set_xlabel('Humidity ')
ax.set_ylabel('Temperature')
plt.show()

# %%
sns.catplot(x="Moisture",y="Soil Type" ,kind="bar",data=ds)
plt.show()

# %%
sns.catplot(x="Nitrogen",y="Soil Type" ,kind="bar",data=ds)
plt.show()
sns.catplot(x="Potassium",y="Soil Type" ,kind="bar",data=ds)
plt.show()

# %%
sns.catplot(x="Potassium",y="Soil Type",kind="box",data=ds)
plt.show()

# %%
cat_list=[i for i in ds.select_dtypes("object")]
cat_list
# Out:
# ['Soil Type', 'Crop Type', 'Fertilizer Name']

# %%
for i in cat_list:
    ds[i] = ds[i].factorize()[0]
    ds
plt.figure(figsize=(12,12))
sns.heatmap(ds.corr(),annot=True,linewidths=0.7,cmap="viridis",fmt=".2f")
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
# Generate some example data (replace this with your actual data)
X = np.random.rand(100, 3)  # Feature matrix with 100 samples and 3 features
Y = np.random.randint(0, 2, size=100)  # Target variable with binary labels (0 or 1)

# %%
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (90, 3)
# (10, 3)
# (90,)
# (10,)

# %%
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV,ElasticNet,ElasticNetCV,LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn import neighbors
from sklearn.svm import SVR

# %%
dt=DecisionTreeRegressor()
dt.fit(X_train,Y_train)
y_predict = dt.predict(X_test)
dt.score(X_train,Y_train)
dt.score(X_test,Y_test)
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(r2_score(Y_test, y_predict)*100)
print(mean_squared_error(Y_test,y_predict))
print(mean_absolute_error(Y_test,y_predict))
# Out:
# -108.3333333333333
# 0.5
# 0.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
wide = (21, 9) # Wide size for figure size.
large_square = (30, 30)
ds=pd.read_csv('C:/Users/Tanuja/OneDrive/Desktop/CROP/cropFertilizerandanalysis Prediction.csv')
ds.head(20)
ds.shape
ds.info()
ds.columns
ds.describe()
ds.dtypes
ds.isnull().sum()
#unique values in dataset
ds.nunique()
plt.figure(figsize=(8, 6))
sns.countplot(data=ds, x='Crop Type')
plt.xlabel('Crop Type')
plt.ylabel('Count')
plt.show()
plt.figure(figsize=(8, 6))
sns.countplot(data=ds, x='Soil Type')
plt.xlabel('Soil Type')
plt.ylabel('Count')
plt.show()
# Group the data by soil type
ds1 = ds.groupby("Soil Type")["Nitrogen"].mean()
ds1.plot(kind="bar")
# Show the plot
plt.show()
# Group the data by soil type
ds1 = ds.groupby("Soil Type")["Potassium"].mean()
ds1.plot(kind="bar")
# Show the plot
plt.show()
# Group the data by soil type
ds1 = ds.groupby("Soil Type")["Phosphorous"].mean()
ds1.plot(kind="bar")
# Show the plot
plt.show()
ds.hist()
plt.show()
ds["Temparature"].value_counts()
ds["Humidity "].value_counts()
Temparature = ds.groupby('Temparature')['Humidity '].mean().sort_values(ascending=False)
# Create horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 20))
ax.barh(Temparature.index, Temparature.values)
ax.set_xlabel('Humidity ')
ax.set_ylabel('Temperature')
plt.show()
sns.catplot(x="Moisture",y="Soil Type" ,kind="bar",data=ds)
plt.show()
sns.catplot(x="Nitrogen",y="Soil Type" ,kind="bar",data=ds)
plt.show()
sns.catplot(x="Potassium",y="Soil Type" ,kind="bar",data=ds)
plt.show()
sns.catplot(x="Potassium",y="Soil Type",kind="box",data=ds)
plt.show()
cat_list=[i for i in ds.select_dtypes("object")]
cat_list
for i in cat_list:
    ds[i] = ds[i].factorize()[0]
    ds
plt.figure(figsize=(12,12))
sns.heatmap(ds.corr(),annot=True,linewidths=0.7,cmap="viridis",fmt=".2f")
plt.show()
import numpy as np
from sklearn.model_selection import train_test_split
# Generate some example data (replace this with your actual data)
X = np.random.rand(100, 3)  # Feature matrix with 100 samples and 3 features
Y = np.random.randint(0, 2, size=100)  # Target variable with binary labels (0 or 1)
# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV,ElasticNet,ElasticNetCV,LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn import neighbors
from sklearn.svm import SVR
dt=DecisionTreeRegressor()
dt.fit(X_train,Y_train)
y_predict = dt.predict(X_test)
dt.score(X_train,Y_train)
dt.score(X_test,Y_test)
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(r2_score(Y_test, y_predict)*100)
print(mean_squared_error(Y_test,y_predict))
print(mean_absolute_error(Y_test,y_predict))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temparature      99 non-null     int64
#  1   Humidity         99 non-null     int64
#  2   Moisture         99 non-null     int64
#  3   Soil Type        99 non-null     object
#  4   Crop Type        99 non-null     object
#  5   Nitrogen         99 non-null     int64
#  6   Potassium        99 non-null     int64
#  7   Phosphorous      99 non-null     int64
#  8   Fertilizer Name  99 non-null     object
# dtypes: int64(6), object(3)
# memory usage: 7.1+ KB
# (90, 3)
# (10, 3)
# (90,)
# (10,)
# -25.0
# 0.3
# 0.3
